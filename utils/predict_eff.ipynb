# %%
from sklearn.metrics import classification_report
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.efficientnet import preprocess_input
import tensorflow as tf
from tensorflow.python.keras.backend import set_session
import numpy as np
from PIL import Image
from os import listdir
from os.path import join

from tensorflow.keras import layers

# %%
MODEL_NAME= "cats_efficientnetb0-Noise-Brightness-V1.keras"
SAMPLE_PATH = './normal_imgs'
IMAGE_SIZE = 224  # EfficientNetB0 expects 224x224 images

dict={
    0: 'pallas',
    1: 'persian',
    2: 'ragdoll',
    3: 'singapura',
    4: 'sphynx'
}

# %%
def classify(model, image):
    result = model.predict(image)
    themax = np.argmax(result)
    return (dict[themax], result[0][themax], themax)

# %%
def load_image_for_efficientnet(image_fname):
    img = Image.open(image_fname)
    img = img.resize((224, 224))  # EfficientNet expects 224x224
    imgarray = np.array(img) 
    final = np.expand_dims(imgarray, axis=0)
    return preprocess_input(final)  # Use EfficientNet's preprocessing

# %%
# test = tf.keras.preprocessing.image_dataset_from_directory(
#     "./samples",
#     image_size=(IMAGE_SIZE, IMAGE_SIZE),
#     batch_size=32,
#     label_mode='int',
#     shuffle=False
# )

# %%
def main():
    print("Loading model from ", MODEL_NAME)
    model = load_model(MODEL_NAME)
    print("Done")

    print("Now classifying files in ", SAMPLE_PATH)

    sample_files = listdir(SAMPLE_PATH)
    results = []
    label_gt = []
    predicted_label = []
    for filename in sample_files:
        filename = join(SAMPLE_PATH, filename)
        # img = load_image(filename)
        img = load_image_for_efficientnet(filename)
        label, prob, _ = classify(model, img)
        results.append((filename, label, prob))
        predicted_label.append(label)
        print("We think with certainty %3.2f that image %s is %s." % (prob, filename, label))

    for file in sample_files:
        for label in dict.values():
            if label.lower() in file.lower():
                # print(f"File {file} contains label {label}")
                label_gt.append(label)
    print("\nClassification results:")
    print(classification_report(label_gt, predicted_label))


if __name__ == '__main__':
    main()
# Out:
# Loading model from  cats_efficientnetb0-Noise-Brightness-V1.keras
# Done
# Now classifying files in  ./normal_imgs
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_88.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 0.98 that image ./normal_imgs/Ragdolls_ragdoll_688.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_677.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_813.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_501.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_461.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 0.99 that image ./normal_imgs/Persian_cats_persian_635.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_609.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_500.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_423.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_609.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_150.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_780.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_569.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_728.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_637.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_847.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_192.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_742.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_409.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 0.81 that image ./normal_imgs/Ragdolls_ragdoll_502.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_Persian_179.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_780.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_346.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_661.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_795.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_637.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_554.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_746.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_Persian_83.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_467.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 0.98 that image ./normal_imgs/Persian_cats_persian_550.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_24.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_579.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_Persian_197.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_801.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_784.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_329.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 0.70 that image ./normal_imgs/Ragdolls_ragdoll_513.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_785.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.70 that image ./normal_imgs/Singapura_cats_singapura_746.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_419.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_894.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_551.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_545.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_747.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_70.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_632.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_470.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_432.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_909.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_355.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_464.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_276.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_624.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_698.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_397.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_934.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_358.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_827.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_469.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_358.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_Persian_125.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_454.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_Ragdoll_93.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_826.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_775.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_167.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_333.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.99 that image ./normal_imgs/Ragdolls_ragdoll_832.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_246.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_913.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_549.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_207.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_Sphynx_213.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_443.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.94 that image ./normal_imgs/Persian_cats_persian_522.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_654.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_126.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 0.99 that image ./normal_imgs/Singapura_cats_singapura_286.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_330.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_324.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.85 that image ./normal_imgs/Persian_cats_persian_697.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_429.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_319.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_57.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_819.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_825.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_Sphynx_65.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_292.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_650.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_320.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_527.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_47.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 0.96 that image ./normal_imgs/Ragdolls_ragdoll_799.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_679.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_123.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# We think with certainty 0.66 that image ./normal_imgs/Persian_cats_persian_335.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_309.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_Persian_137.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_645.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_Ragdoll_202.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_565.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_863.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.99 that image ./normal_imgs/Ragdolls_Ragdoll_81.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_320.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_Sphynx_175.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_968.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_241.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_Ragdoll_149.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_Sphynx_74.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_405.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_647.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_242.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_573.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_295.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_445.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_295.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_451.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_486.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_822.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_486.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.98 that image ./normal_imgs/Persian_cats_persian_860.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_51.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_487.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_943.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_437.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 0.99 that image ./normal_imgs/Persian_cats_persian_299.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_755.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_273.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_147.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_351.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_378.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_449.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.98 that image ./normal_imgs/Sphynx_cats_sphynx_620.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 0.98 that image ./normal_imgs/Singapura_cats_singapura_49.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_754.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_595.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 0.97 that image ./normal_imgs/Persian_cats_persian_924.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_517.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_476.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_742.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_675.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_Sphynx_193.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_Sphynx_187.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.85 that image ./normal_imgs/Ragdolls_ragdoll_971.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_756.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_347.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_489.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_Ragdoll_227.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_517.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_503.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_Ragdoll_5.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 0.73 that image ./normal_imgs/Ragdolls_ragdoll_409.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_512.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_948.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_974.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_800.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_472.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.96 that image ./normal_imgs/Singapura_cats_singapura_99.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_711.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.70 that image ./normal_imgs/Persian_cats_persian_659.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_301.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_801.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_506.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_705.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_314.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_18.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_383.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_30.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_707.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.97 that image ./normal_imgs/Ragdolls_Ragdoll_195.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_Sphynx_80.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_672.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_Persian_114.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_464.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 0.99 that image ./normal_imgs/Ragdolls_ragdoll_989.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_751.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 0.95 that image ./normal_imgs/Pallas_cats_pallas_706.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_317.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 0.59 that image ./normal_imgs/Pallas_cats_pallas_31.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_25.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_166.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_73.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.94 that image ./normal_imgs/Ragdolls_ragdoll_722.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_441.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_521.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_416.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.44 that image ./normal_imgs/Persian_cats_persian_199.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_416.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_563.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_910.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_172.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_938.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_864.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_694.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_43.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_951.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_603.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_Sphynx_245.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_366.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.92 that image ./normal_imgs/Ragdolls_ragdoll_523.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_788.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_481.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_495.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_165.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_171.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_873.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 0.99 that image ./normal_imgs/Ragdolls_ragdoll_640.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_400.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_873.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_763.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.77 that image ./normal_imgs/Singapura_cats_singapura_170.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_213.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_158.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 0.97 that image ./normal_imgs/Singapura_cats_singapura_160.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_565.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# We think with certainty 0.89 that image ./normal_imgs/Persian_cats_persian_773.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_Sphynx_23.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_438.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# We think with certainty 0.92 that image ./normal_imgs/Persian_cats_persian_820.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_565.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_645.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_725.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_363.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_321.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_92.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.71 that image ./normal_imgs/Persian_cats_persian_799.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_764.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_Ragdoll_135.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_189.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_445.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_Ragdoll_257.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_479.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_525.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.51 that image ./normal_imgs/Ragdolls_ragdoll_17.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_256.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_163.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.97 that image ./normal_imgs/Singapura_cats_singapura_228.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Sphynx_cats_sphynx_685.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_572.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_13.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.99 that image ./normal_imgs/Persian_cats_persian_215.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 0.40 that image ./normal_imgs/Ragdolls_ragdoll_849.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Singapura_cats_singapura_374.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_759.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Pallas_cats_pallas_85.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 1.00 that image ./normal_imgs/Ragdolls_ragdoll_444.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# We think with certainty 1.00 that image ./normal_imgs/Persian_cats_persian_956.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# We think with certainty 0.92 that image ./normal_imgs/Persian_cats_Persian_63.jpg is persian.
#
# Classification results:
#               precision    recall  f1-score   support
#
#       pallas       0.98      0.98      0.98        50
#      persian       0.90      0.86      0.88        50
#      ragdoll       0.88      0.90      0.89        50
#    singapura       0.96      0.96      0.96        50
#       sphynx       0.98      1.00      0.99        50
#
#     accuracy                           0.94       250
#    macro avg       0.94      0.94      0.94       250
# weighted avg       0.94      0.94      0.94       250
