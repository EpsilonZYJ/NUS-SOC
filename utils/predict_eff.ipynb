# %%
from sklearn.metrics import classification_report
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.efficientnet import preprocess_input
import tensorflow as tf
from tensorflow.python.keras.backend import set_session
import numpy as np
from PIL import Image
from os import listdir
from os.path import join

from tensorflow.keras import layers

# %%
MODEL_NAME= "cats_efficientnetb0.keras"
SAMPLE_PATH = './samples'
IMAGE_SIZE = 224  # EfficientNetB0 expects 224x224 images

dict={
    0: 'pallas',
    1: 'persian',
    2: 'ragdoll',
    3: 'singapura',
    4: 'sphynx'
}

# %%
def classify(model, image):
    result = model.predict(image)
    themax = np.argmax(result)
    return (dict[themax], result[0][themax], themax)

# %%
def load_image_for_efficientnet(image_fname):
    img = Image.open(image_fname)
    img = img.resize((224, 224))  # EfficientNet expects 224x224
    imgarray = np.array(img) 
    final = np.expand_dims(imgarray, axis=0)
    return preprocess_input(final)  # Use EfficientNet's preprocessing

# %%
# test = tf.keras.preprocessing.image_dataset_from_directory(
#     "./samples",
#     image_size=(IMAGE_SIZE, IMAGE_SIZE),
#     batch_size=32,
#     label_mode='int',
#     shuffle=False
# )

# %%
def main():
    print("Loading model from ", MODEL_NAME)
    model = load_model(MODEL_NAME)
    print("Done")

    print("Now classifying files in ", SAMPLE_PATH)

    sample_files = listdir(SAMPLE_PATH)
    results = []
    label_gt = []
    predicted_label = []
    for filename in sample_files:
        filename = join(SAMPLE_PATH, filename)
        # img = load_image(filename)
        img = load_image_for_efficientnet(filename)
        label, prob, _ = classify(model, img)
        results.append((filename, label, prob))
        predicted_label.append(label)
        print("We think with certainty %3.2f that image %s is %s." % (prob, filename, label))

    for file in sample_files:
        for label in dict.values():
            if label.lower() in file.lower():
                # print(f"File {file} contains label {label}")
                label_gt.append(label)
    print("\nClassification results:")
    print(classification_report(label_gt, predicted_label))


if __name__ == '__main__':
    main()
# Out:
# Loading model from  cats_efficientnetb0.keras
# Done
# Now classifying files in  ./samples
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 876ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_200.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_201.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_202.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_203.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_204.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_205.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_206.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_207.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_208.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_209.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_211.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_212.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_213.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_214.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_215.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_216.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_217.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_218.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_219.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_221.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_222.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_223.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_224.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_225.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_226.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_227.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_229.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_231.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_233.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_234.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_235.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_236.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_238.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_239.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_240.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_243.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Pallas cats_244.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_21.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_22.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_23.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_24.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_25.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 0.97 that image ./samples\Persian cat_26.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.51 that image ./samples\Persian cat_28.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_29.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_30.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 0.82 that image ./samples\Persian cat_31.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_32.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.99 that image ./samples\Persian cat_33.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_34.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_35.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_37.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_38.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_39.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_40.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_41.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_42.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_43.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 0.97 that image ./samples\Persian cat_44.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_47.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 0.87 that image ./samples\Persian cat_48.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_49.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_52.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_53.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_54.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_55.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.99 that image ./samples\Persian cat_57.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_58.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# We think with certainty 0.69 that image ./samples\Persian cat_59.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_61.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_62.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_64.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 0.99 that image ./samples\Persian cat_65.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 0.73 that image ./samples\Persian cat_66.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_67.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.99 that image ./samples\Persian cat_69.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_70.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# We think with certainty 0.97 that image ./samples\Persian cat_71.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_72.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_73.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 0.62 that image ./samples\Persian cat_74.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_75.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_77.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_78.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 0.98 that image ./samples\Persian cat_79.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_80.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_81.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_82.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.66 that image ./samples\Persian cat_83.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_85.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_86.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_88.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_89.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_90.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.98 that image ./samples\Persian cat_91.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_93.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.96 that image ./samples\Persian cat_94.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_97.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_98.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Persian cat_99.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Persian1.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Persian2.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Ragdoll1.JPG is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Ragdoll2.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_284.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_285.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.99 that image ./samples\Ragdolls_289.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.92 that image ./samples\Ragdolls_290.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_291.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.99 that image ./samples\Ragdolls_292.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_293.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_294.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_295.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_296.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 0.76 that image ./samples\Ragdolls_298.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_299.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_302.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.99 that image ./samples\Ragdolls_304.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_305.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_308.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_309.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_310.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_311.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.60 that image ./samples\Ragdolls_312.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_314.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 0.99 that image ./samples\Ragdolls_315.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_316.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_319.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_320.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_321.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_323.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_324.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_325.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_326.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_327.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 0.68 that image ./samples\Ragdolls_328.jpg is pallas.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_329.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_333.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 0.97 that image ./samples\Ragdolls_334.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_335.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_336.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_338.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.99 that image ./samples\Ragdolls_339.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_340.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_342.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_343.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 0.79 that image ./samples\Ragdolls_345.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_346.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_347.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_348.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_349.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_350.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_351.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.99 that image ./samples\Ragdolls_352.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_353.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_354.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_355.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_356.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_357.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_358.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.99 that image ./samples\Ragdolls_359.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_360.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_361.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_362.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_363.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_364.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 0.98 that image ./samples\Ragdolls_366.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Ragdolls_367.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_100.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_101.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 0.52 that image ./samples\singapura cat photo_102.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_104.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_105.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_106.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_107.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_109.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_110.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_111.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_112.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_113.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_114.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_115.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_116.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_117.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_120.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_121.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.99 that image ./samples\singapura cat photo_122.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_124.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_125.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_126.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 0.99 that image ./samples\singapura cat photo_127.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_128.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.93 that image ./samples\singapura cat photo_130.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_131.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_132.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_133.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_134.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_136.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_137.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_138.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_140.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_141.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_142.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_143.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_145.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_146.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_147.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_148.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_150.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_151.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_152.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_154.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_155.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_156.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_157.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 0.68 that image ./samples\singapura cat photo_158.jpg is persian.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_159.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_160.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_161.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_163.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_164.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_165.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_166.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 0.99 that image ./samples\singapura cat photo_167.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_168.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_171.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_172.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 0.84 that image ./samples\singapura cat photo_173.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.55 that image ./samples\singapura cat photo_174.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_176.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_178.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_179.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_181.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_182.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_183.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_56.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.99 that image ./samples\singapura cat photo_57.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_58.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_59.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_62.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_63.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_64.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_65.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.99 that image ./samples\singapura cat photo_66.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_67.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_68.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_70.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_71.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_72.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_73.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_74.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_75.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_76.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_77.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_78.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_79.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_80.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_81.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_82.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.99 that image ./samples\singapura cat photo_83.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_84.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_85.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_86.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_87.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_88.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 0.62 that image ./samples\singapura cat photo_90.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_91.jpg is ragdoll.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_92.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_93.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_96.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_97.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 0.99 that image ./samples\singapura cat photo_98.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\singapura cat photo_99.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Singapura1.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# We think with certainty 1.00 that image ./samples\Singapura2.jpg is singapura.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# We think with certainty 0.67 that image ./samples\Sphynx cat_117.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_118.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 0.74 that image ./samples\Sphynx cat_119.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_120.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_122.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_123.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_124.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_125.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_126.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_127.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_128.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_129.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_130.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_131.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_132.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_133.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_135.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_136.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_137.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_138.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_139.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_140.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_143.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_145.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 0.98 that image ./samples\Sphynx cat_146.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_147.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_148.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_149.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_150.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_152.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_153.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_154.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_155.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# We think with certainty 1.00 that image ./samples\Sphynx cat_157.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Sphynx1.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# We think with certainty 1.00 that image ./samples\Sphynx2.jpg is sphynx.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# We think with certainty 1.00 that image ./samples\Sphynx3.jpg is sphynx.
#
# Classification results:
#               precision    recall  f1-score   support
#
#       pallas       0.97      0.97      0.97        37
#      persian       0.97      0.92      0.94        65
#      ragdoll       0.90      0.97      0.93        66
#    singapura       0.99      0.94      0.97       107
#       sphynx       0.93      1.00      0.96        37
#
#     accuracy                           0.96       312
#    macro avg       0.95      0.96      0.96       312
# weighted avg       0.96      0.96      0.96       312
